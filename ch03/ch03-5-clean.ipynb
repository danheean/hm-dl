# %%
import tf_keras as keras
import tf_keras.layers as layers

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    "../data/Pistachio_Image_Dataset",
    image_size=(224, 224),
    batch_size=16,
    validation_split=0.2,
    subset="both",
    seed=42
)
# Out:
# Found 2148 files belonging to 2 classes.
# Using 1719 files for training.
# Using 429 files for validation.
# 2025-08-06 11:08:32.637988: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-08-06 11:08:32.638010: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-08-06 11:08:32.638017: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-08-06 11:08:32.638028: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-08-06 11:08:32.638037: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import tensorflow as tf
import tensorflow_hub as hub

kaggle_efficientb0_base = hub.KerasLayer('https://www.kaggle.com/models/tensorflow/efficientnet/frameworks/TensorFlow2/variations/b0-feature-vector/versions/1')
# Out:
# /Users/jurepi/Work/Study/hm-dl/.venv/lib/python3.10/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = layers.Rescaling(1./255)(inputs)
x = kaggle_efficientb0_base(x)
x = layers.Dense(128, activation='softmax')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs, outputs)

rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model.compile(
    optimizer=rmsprop,
    loss='binary_crossentropy', 
    metrics=['accuracy'])

hist = model.fit(train_ds, epochs=30, validation_data=val_ds)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Epoch 1/30
# 2025-08-06 11:08:41.783442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 108/108 [==============================] - 9s 41ms/step - loss: 0.6889 - accuracy: 0.5829 - val_loss: 0.6857 - val_accuracy: 0.5431
# Epoch 2/30
# 108/108 [==============================] - 2s 20ms/step - loss: 0.6796 - accuracy: 0.5812 - val_loss: 0.6782 - val_accuracy: 0.5431
# Epoch 3/30
# 108/108 [==============================] - 2s 20ms/step - loss: 0.6701 - accuracy: 0.5812 - val_loss: 0.6681 - val_accuracy: 0.5431
# Epoch 4/30
# 108/108 [==============================] - 2s 20ms/step - loss: 0.6584 - accuracy: 0.6318 - val_loss: 0.6542 - val_accuracy: 0.7156
# Epoch 5/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.6441 - accuracy: 0.8022 - val_loss: 0.6380 - val_accuracy: 0.8648
# Epoch 6/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.6299 - accuracy: 0.8837 - val_loss: 0.6248 - val_accuracy: 0.8998
# Epoch 7/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.6183 - accuracy: 0.9087 - val_loss: 0.6137 - val_accuracy: 0.9231
# Epoch 8/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.6081 - accuracy: 0.9162 - val_loss: 0.6044 - val_accuracy: 0.9324
# Epoch 9/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5998 - accuracy: 0.9244 - val_loss: 0.5969 - val_accuracy: 0.9347
# Epoch 10/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5927 - accuracy: 0.9314 - val_loss: 0.5902 - val_accuracy: 0.9371
# Epoch 11/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5861 - accuracy: 0.9412 - val_loss: 0.5840 - val_accuracy: 0.9441
# Epoch 12/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5800 - accuracy: 0.9471 - val_loss: 0.5783 - val_accuracy: 0.9487
# Epoch 13/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5743 - accuracy: 0.9500 - val_loss: 0.5730 - val_accuracy: 0.9487
# Epoch 14/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5688 - accuracy: 0.9517 - val_loss: 0.5678 - val_accuracy: 0.9534
# Epoch 15/30
# 108/108 [==============================] - 2s 21ms/step - loss: 0.5635 - accuracy: 0.9575 - val_loss: 0.5628 - val_accuracy: 0.9557
# Epoch 16/30
# 108/108 [==============================] - 2s 22ms/step - loss: 0.5583 - accuracy: 0.9604 - val_loss: 0.5580 - val_accuracy: 0.9557
# Epoch 17/30
# 108/108 [==============================] - 2s 22ms/step - loss: 0.5533 - accuracy: 0.9634 - val_loss: 0.5532 - val_accuracy: 0.9604
# Epoch 18/30
# 108/108 [==============================] - 2s 22ms/step - loss: 0.5484 - accuracy: 0.9634 - val_loss: 0.5485 - val_accuracy: 0.9604
# Epoch 19/30
# 108/108 [==============================] - 2s 22ms/step - loss: 0.5435 - accuracy: 0.9657 - val_loss: 0.5440 - val_accuracy: 0.9627
# Epoch 20/30
# 108/108 [==============================] - 3s 23ms/step - loss: 0.5389 - accuracy: 0.9657 - val_loss: 0.5396 - val_accuracy: 0.9627
# Epoch 21/30
# 108/108 [==============================] - 2s 23ms/step - loss: 0.5342 - accuracy: 0.9668 - val_loss: 0.5352 - val_accuracy: 0.9627
# Epoch 22/30
# 108/108 [==============================] - 2s 23ms/step - loss: 0.5297 - accuracy: 0.9697 - val_loss: 0.5309 - val_accuracy: 0.9650
# Epoch 23/30
# 108/108 [==============================] - 3s 24ms/step - loss: 0.5252 - accuracy: 0.9692 - val_loss: 0.5266 - val_accuracy: 0.9650
# Epoch 24/30
# 108/108 [==============================] - 3s 24ms/step - loss: 0.5208 - accuracy: 0.9703 - val_loss: 0.5224 - val_accuracy: 0.9650
# Epoch 25/30
# 108/108 [==============================] - 3s 24ms/step - loss: 0.5164 - accuracy: 0.9697 - val_loss: 0.5184 - val_accuracy: 0.9674
# Epoch 26/30
# 108/108 [==============================] - 3s 25ms/step - loss: 0.5121 - accuracy: 0.9692 - val_loss: 0.5142 - val_accuracy: 0.9674
# Epoch 27/30
# 108/108 [==============================] - 3s 25ms/step - loss: 0.5078 - accuracy: 0.9721 - val_loss: 0.5102 - val_accuracy: 0.9674
# Epoch 28/30
# 108/108 [==============================] - 3s 26ms/step - loss: 0.5036 - accuracy: 0.9715 - val_loss: 0.5061 - val_accuracy: 0.9674
# Epoch 29/30
# 108/108 [==============================] - 3s 28ms/step - loss: 0.4994 - accuracy: 0.9709 - val_loss: 0.5021 - val_accuracy: 0.9674
# Epoch 30/30
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4952 - accuracy: 0.9727 - val_loss: 0.4982 - val_accuracy: 0.9674

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'AppleGothic'  # 맥OS용 한글 폰트
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 부호 깨짐 방지

epochs = 30
fig, axs = plt.subplots(1, 2, figsize=(16, 4))
axs[0].plot(range(1, epochs+1), hist.history["loss"], label="loss")
axs[0].plot(range(1, epochs+1), hist.history["val_loss"], label="val_loss")
axs[0].set_xticks(range(1, epochs+1))
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(range(1, epochs+1), hist.history["accuracy"], label="accuracy")
axs[1].plot(range(1, epochs+1), hist.history["val_accuracy"], label="val_accuracy")
axs[1].set_xticks(range(1, epochs+1))
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Accuracy")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# 현재 학습 상태 확인
print("=== 최종 학습 결과 ===")
if 'hist' in globals():
    final_train_acc = hist.history['accuracy'][-1]
    final_val_acc = hist.history['val_accuracy'][-1]
    
    print(f"훈련 정확도: {final_train_acc:.1%}")
    print(f"검증 정확도: {final_val_acc:.1%}")
    
    # 과적합 체크
    overfitting = final_train_acc - final_val_acc
    print(f"과적합 정도: {overfitting:.1%}")
    
    if overfitting > 0.1:  # 10% 이상 차이
        print("⚠️ 약간의 과적합 발생")
    else:
        print("✅ 좋은 일반화 성능")
        

# 베스트 검증 정확도
best_val_acc = max(hist.history['val_accuracy'])
best_epoch = hist.history['val_accuracy'].index(best_val_acc) + 1
print(f"\n최고 검증 정확도: {best_val_acc:.1%} (Epoch {best_epoch})")
# Out:
# === 최종 학습 결과 ===
# 훈련 정확도: 97.3%
# 검증 정확도: 96.7%
# 과적합 정도: 0.5%
# ✅ 좋은 일반화 성능
#
# 최고 검증 정확도: 96.7% (Epoch 25)
